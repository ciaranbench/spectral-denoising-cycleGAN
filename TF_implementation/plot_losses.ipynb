# %%
import numpy as np
#history=np.load('my_history.npy',allow_pickle='TRUE').item()

# %%
#print(history)

# %%
a = []
b = []
for i in range((50)):
    v = np.load('./epoch_' + str(i) + '/valid_loss_' + str(i) + '.npy')
    d = np.load('./epoch_' + str(i) + '/valid_loss_sup_' + str(i) + '.npy')
    a.append(v)
    b.append(d)

# %%
import matplotlib.pyplot as plt

plt.plot(a)

# %%
plt.plot(b)
