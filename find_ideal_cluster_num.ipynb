# %%
# Here, we compute the ideal cluster number for computing the unsupervised validation metric
# This corresponds to the number of clusters that produces the highest calinski_harabasz_score 
# on the high SNR validation set

from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
import numpy as np
import matplotlib.pyplot as plt

scores = []
cluster_nums = range(2,20,2)
clean_va = np.squeeze(np.load('ln_valid_set.npy'))
for i in range(2,20,2):
    kmeans_model = KMeans(n_clusters=i, random_state=4).fit(clean_va)
    labels = kmeans_model.labels_
    scores.append(metrics.calinski_harabasz_score(clean_va, labels))
# Out:
# /home/ciaran/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 2
# /home/ciaran/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 4
# /home/ciaran/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 6
# /home/ciaran/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 8
# ...

# %%
plt.plot(cluster_nums,scores)
plt.xlabel('Cluster number')
plt.ylabel('Calinski Harabasz Score')
# Out:
# Text(0, 0.5, 'Calinski Harabasz Score')

# %%
cluster_nums[int(np.squeeze(np.where(scores == np.max(scores))))]
# Out:
# 8
